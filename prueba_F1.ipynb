# %%
import pandas as pd

# %%
resultados_f1 = pd.read_excel("Resultados_F1.xlsx")
resultados_f1.head()
# Out:
#    Unnamed: 0        Grand Prix  Year                  Winner  \
# 0           0     Great Britain  1950         Nino Farina FAR
# 1           1            Monaco  1950  Juan Manuel Fangio FAN
# 2           2  Indianapolis 500  1950    Johnnie  Parsons PAR
# 3           3       Switzerland  1950         Nino Farina FAR
# 4           4           Belgium  1950  Juan Manuel Fangio FAN
#
#                         Car  Laps     Time      Escala
# 0                Alfa Romeo    70  2:13:23  333.458333
# 1                Alfa Romeo   100  3:13:18  483.250000
# 2  Kurtis Kraft Offenhauser   138  2:46:55  417.291667
# 3                Alfa Romeo    42  2:02:53  307.208333
# 4                Alfa Romeo    35  2:47:26  418.583333

# %%
df = pd.read_csv("F1_Race_Results.csv")
#Formula 1 Dataset 🏎 🏁 (1950 - 2021)

# %%
df_1=pd.read_excel('Fallecidos_F1.xlsx')
df_1
# Out:
#           Unnamed: 0           Unnamed: 1 Unnamed: 2  \
# 0             Piloto                Fecha       Edad
# 1       ONGAIS Danny  2022-02-26 00:00:00    79 años
# 2      BONDURANT Bob  2021-11-12 00:00:00    88 años
# 3        HARRIS Mike  2021-11-08 00:00:00    82 años
# 4    VACCARELLA Nino  2021-09-22 00:00:00    88 años
# ..               ...                  ...        ...
# 607       BROWN Walt  1951-07-29 00:00:00    39 años
# 608      GREEN Cecil  1951-07-29 00:00:00    31 años
# 609      ACHARD Jean  1951-07-14 00:00:00    33 años
# 610   SOMMER Raymond  1950-09-10 00:00:00    44 años
# 611          FRY Joe  1950-07-29 00:00:00    34 años
#
#                                           Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                                              Causa         NaN        NaN
# 1                             Insuffisance cardiaque         NaN        NaN
# 2                                                NaN         NaN        NaN
# ...

# %%
df
# Out:
#             Grand Prix         Date                  Winner  \
# 0        Great Britain  13 May 1950         Nino Farina FAR
# 1               Monaco  21 May 1950  Juan Manuel Fangio FAN
# 2     Indianapolis 500  30 May 1950    Johnnie  Parsons PAR
# 3          Switzerland  04 Jun 1950         Nino Farina FAR
# 4              Belgium  18 Jun 1950  Juan Manuel Fangio FAN
# ...                ...          ...                     ...
# 1055            Mexico  07 Nov 2021      Max Verstappen VER
# 1056            Brazil  14 Nov 2021      Lewis Hamilton HAM
# 1057             Qatar  21 Nov 2021      Lewis Hamilton HAM
# 1058      Saudi Arabia  05 Dec 2021      Lewis Hamilton HAM
# 1059         Abu Dhabi  12 Dec 2021      Max Verstappen VER
#
#                            Car   Laps         Time
# 0                   Alfa Romeo   70.0  2:13:23.600
# 1                   Alfa Romeo  100.0  3:13:18.700
# 2     Kurtis Kraft Offenhauser  138.0  2:46:55.970
# ...

# %%
df['Grand Prix'].unique()
# Out:
# array(['Great Britain', 'Monaco', 'Indianapolis 500', 'Switzerland',
#        'Belgium', 'France', 'Italy', 'Germany', 'Spain', 'Netherlands',
#        'Argentina', 'Pescara', 'Portugal', 'Morocco', 'United States',
#        'South Africa', 'Mexico', 'Austria', 'Canada', 'Brazil', 'Sweden',
#        'USA West', 'USA East', 'Japan', 'San Marino', 'Las Vegas',
#        'Detroit', 'Europe', 'Dallas', 'Australia', 'Hungary', 'Pacific',
#        'Luxembourg', 'Malaysia', 'Bahrain', 'China', 'Turkey',
#        'Singapore', 'Abu Dhabi', 'South Korea', 'India', 'Russia',
#        'Azerbaijan', 'Styria', '70th Anniversary', 'Tuscany', 'Eifel',
#        'Emilia Romagna', 'Sakhir', 'Qatar', 'Saudi Arabia'], dtype=object)

# %%
df.info
# Out:
# <bound method DataFrame.info of             Grand Prix         Date                  Winner  \
# 0        Great Britain  13 May 1950         Nino Farina FAR
# 1               Monaco  21 May 1950  Juan Manuel Fangio FAN
# 2     Indianapolis 500  30 May 1950    Johnnie  Parsons PAR
# 3          Switzerland  04 Jun 1950         Nino Farina FAR
# 4              Belgium  18 Jun 1950  Juan Manuel Fangio FAN
# ...                ...          ...                     ...
# 1055            Mexico  07 Nov 2021      Max Verstappen VER
# 1056            Brazil  14 Nov 2021      Lewis Hamilton HAM
# 1057             Qatar  21 Nov 2021      Lewis Hamilton HAM
# 1058      Saudi Arabia  05 Dec 2021      Lewis Hamilton HAM
# 1059         Abu Dhabi  12 Dec 2021      Max Verstappen VER
#
#                            Car   Laps         Time
# 0                   Alfa Romeo   70.0  2:13:23.600
# 1                   Alfa Romeo  100.0  3:13:18.700
# 2     Kurtis Kraft Offenhauser  138.0  2:46:55.970
# ...
